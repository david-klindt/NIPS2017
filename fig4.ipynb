# %% [markdown]
# # Separating two types of neurons - Figure 4

# %%
# Load General Modules
# %matplotlib inline
import matplotlib
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps
from scipy.stats import chi
import scipy as sp
from scipy import signal
from sklearn import linear_model
import pickle
import datetime
import time
import os
# %load_ext autoreload
# %autoreload 2

# Local modules (scripts need to be in folder)
import CNN
import generate_neurons
import generate_data
import pre_process
import GLMs
import training

# Tensorflow needs to be LAST import
import tensorflow as tf
print(tf.__version__)
# Out:
# /usr/local/lib/python3.4/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# 1.0.0

# %% [markdown]
# ## Fig 4a: Visualize neurons

# %%
#Seeds
np_seed=1
np.random.seed(np_seed)
tf_seed=1

#Parameters:
s=[48,1,32]#sizes of [image(heigth=width), image(depth=channel), mask]
sk=[17]#width=heigth of receptive field and conv kernel
mr=.1#mean response
N=16#neurons

#generate two types
N=18
RF1,True_Kernel1,True_Locations1 = generate_neurons.generate_neurons(np.int(N/2),s[0],sk[0],
                    target_mean_count=mr,centering=False,types=.6,variation=.05,np_seed=np_seed)
generate_neurons.visualize(RF1)
RF2,True_Kernel2,True_Locations2 = generate_neurons.generate_neurons(np.int(N/2),s[0],sk[0],
                    target_mean_count=mr,centering=False,types=1,variation=.05,np_seed=np_seed)
generate_neurons.visualize(RF2)
# Out:
# generate neurons 0.0 finished
# generate neurons 0.0 finished

# %% [markdown]
# ## Fit Model and show clustering - Fig 4b

# %%
start = time.time()
#Seeds
np_seed=1
np.random.seed(np_seed)
tf_seed=1
'''
#Parameters:
s=[48,1,32]#sizes of [image(heigth=width), image(depth=channel), mask]
sk=[17]#width=heigth of receptive field and conv kernel
mr=.1#mean response

#generate two types
N=1000
RF1,True_Kernel1,True_Locations1 = generate_neurons.generate_neurons(np.int(N/2),s[0],sk[0],
                    target_mean_count=mr,centering=False,types=.6,variation=.05,np_seed=np_seed)
RF2,True_Kernel2,True_Locations2 = generate_neurons.generate_neurons(np.int(N/2),s[0],sk[0],
                    target_mean_count=mr,centering=False,types=1,variation=.05,np_seed=np_seed)
RF = np.vstack([RF1,RF2])

#generate data
X_train,X_val,X_test,Y_train,Y_val,GT_test = generate_data.generate_data(RF=RF,tf_seed=tf_seed,
                     num_train=np.int(D*.8),num_val=np.int(D*.2),num_test = 10**4,noise=True)

#calculate spike triggered average to initialize location masks
_,sta=pre_process.STA(X_train,Y_train,32,sk[0])

#NCHW format
X_train=np.reshape(X_train,[s[0],s[0],-1]).transpose([2, 0, 1])[:,None,:,:]
X_val=np.reshape(X_val,[s[0],s[0],-1]).transpose([2, 0, 1])[:,None,:,:]
X_test=np.reshape(X_test,[s[0],s[0],-1]).transpose([2, 0, 1])[:,None,:,:]

print('it took %s s to generate neurons and data'%(time.time()-start))
'''
#Parameters:
D=2**13#data points per neuron

num_kern = [2]#number of bases (conv kernels) to learn per layer

lr= .001 # initial learning rate
reg = [0,.00001,.00004]#[0,.00001,.00003]regularization parameters: L2 Kernels, L1 Mask, L1 Weights
max_runs = 10000 # training steps
batch_size = 512
act_fn=['ID']#activation function per layer in model
weights_constraint=None#'abs'#constrain read out weights to norm=1
kernel_constraint='norm'#sets norm of kernels to 1, instead of using batch norm
stop_crit = [5,2]#[after how many worse steps lower lr, lower how many times]
burn_in=10#allow for burn_in*100 initial runs without triggering stop criterion
split_data=False#set true for large nets to fit on GPU memory

#calculate standard deviation of neural responses (to set output scale)
sd=pre_process.noise_cancel(RF,100,rep=30,np_seed=np_seed)
init_scales = np.array([[0,.01],[0,.001],[np.mean(sd),.01]])#Mean/SD for Kernel,Mask,Weights

#Train Model
start = time.time()
(WK,WM,WW,MSE_train,MSE_val,MSE_test,FEV,FEV_cell,Y_,
log) = training.train(s=s,#        sizes of [image(heigth=width), image(depth=channel), mask]
          sK=sk,#        s - sizes of [kernel1, kernel2, ...] - length of list gives number of layers
          act_fn=act_fn,#      activation functions for each kernel = 'ID' or 'relu'
          init_scales=init_scales,# rows: kernel,mask,weights; columns: mean, sd
          init_lr=lr,# initial learning rate, goes down later
          num_kern=num_kern,#        num_kern - number of kernels per conv layer
          max_runs=max_runs,# maximum number of training steps
          reg=reg,#        regularization weights [Kernel,Mask,Weights]
          batch_size=batch_size,# (max gpu memory?)256 for small one layer, 64 for large multilayer model
          X_train=X_train,
          X_val=X_val,
          X_test=X_test,
          Y_train=Y_train,
          Y_val=Y_val,
          GT_test=GT_test,#Data, X in NCHW format, Y: Neurons x Data
          kernel_constraint=kernel_constraint,#constraint for kernel weights - 'norm' == 1
          weights_constraint=weights_constraint,#constraint on read out weights - 'abs','norm','absnorm'
          mask_constraint=None,#constraint on mask - 'abs'
          final_relu=False,
          stop_crit=stop_crit,#[after how many worse steps lower lr, lower how many times]
          burn_in=burn_in,#allow initial exploration of 100*burn_in runs 
          types=[0,np.int(N/2)],#starting indices of types, default=all same type
          GT_mask=np.vstack([True_Locations1,True_Locations2]),
                      #true locations if known: rows:neurons, columns: x,y location
          tf_seed=tf_seed,#random seed for tensorflow
          np_seed=np_seed,
          split_data=split_data,#whether to go through test and val set in batch_size chunks
          sta=sta,#if provided, take maximum absolute pixel of sta to initialize mask
          sd=sd,#standard deviation of responses, to set the scale
          GT_WK=None,#initialize first conv kernel?
          batch_norm=False,#whether to use batch norm
          bn_cent=False,#center after batch norm?
          verbose='yes')#print training outcome and learned filters every 100 steps, 'yes','no','minimal'


print('run took %s s to optimize'%(time.time()-start))
#Plot Model performance on individual cells
plt.plot(FEV_cell,'.')
plt.xlabel('cell')
plt.ylabel('FEV')
plt.show()

#Plot weight clusters
plt.plot(WW[0,:np.int(N/2)],WW[1,:np.int(N/2)],'og')
plt.plot(WW[0,np.int(N/2):],WW[1,np.int(N/2):],'or')
plt.show()
# Out:
# Before Training:
# FEV =  -0.0454413890839
# Loss/Regularization: 0.016445 MSE, 0.0 kernel, 0.00952015075684 mask, 0.0108977282715 weights
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:1313: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# FEV =  0.749209612608
# Runs: 100; MSE - train: 0.103578, val: 0.103684; lr = 0.001
# best run:  100 0.103684
# Loss/Regularization: 0.00394498 MSE, 0.0 kernel, 0.00694394226074 mask, 0.00696051147461 weights
# FEV =  0.792848020792
# Runs: 200; MSE - train: 0.10337, val: 0.103004; lr = 0.001
# best run:  200 0.103004
# Loss/Regularization: 0.00325854 MSE, 0.0 kernel, 0.00736683227539 mask, 0.00657384460449 weights
# FEV =  0.808177366853
# Runs: 300; MSE - train: 0.102283, val: 0.102762; lr = 0.001
# best run:  300 0.102762
# Loss/Regularization: 0.00301741 MSE, 0.0 kernel, 0.00758944763184 mask, 0.00642828857422 weights
# FEV =  0.816720128059
# Runs: 400; MSE - train: 0.102399, val: 0.102625; lr = 0.001
# best run:  400 0.102625
# Loss/Regularization: 0.00288303 MSE, 0.0 kernel, 0.00763860351563 mask, 0.0063408026123 weights
# FEV =  0.82647562027
# Runs: 500; MSE - train: 0.101755, val: 0.102471; lr = 0.001
# best run:  500 0.102471
# Loss/Regularization: 0.00272957 MSE, 0.0 kernel, 0.00764491210938 mask, 0.00628723876953 weights
# FEV =  0.851725772023
# Runs: 600; MSE - train: 0.10219, val: 0.102068; lr = 0.001
# best run:  600 0.102068
# Loss/Regularization: 0.00233238 MSE, 0.0 kernel, 0.00785604309082 mask, 0.00623894042969 weights
# FEV =  0.872247055173
# Runs: 700; MSE - train: 0.101922, val: 0.101743; lr = 0.001
# best run:  700 0.101743
# Loss/Regularization: 0.00200958 MSE, 0.0 kernel, 0.00797265441895 mask, 0.00617991882324 weights
# FEV =  0.880968116224
# Runs: 800; MSE - train: 0.100633, val: 0.101608; lr = 0.001
# best run:  800 0.101608
# Loss/Regularization: 0.0018724 MSE, 0.0 kernel, 0.00795139770508 mask, 0.00622088989258 weights
# FEV =  0.883920975029
# Runs: 900; MSE - train: 0.101576, val: 0.101561; lr = 0.001
# best run:  900 0.101561
# Loss/Regularization: 0.00182595 MSE, 0.0 kernel, 0.00799755004883 mask, 0.00624703613281 weights
# FEV =  0.885186627507
# Runs: 1000; MSE - train: 0.102017, val: 0.101541; lr = 0.001
# best run:  1000 0.101541
# Loss/Regularization: 0.00180604 MSE, 0.0 kernel, 0.00798650146484 mask, 0.00625200927734 weights
# FEV =  0.885264977813
# Runs: 1100; MSE - train: 0.101567, val: 0.101542; lr = 0.001
# best run:  1000 0.101541
# Loss/Regularization: 0.00180481 MSE, 0.0 kernel, 0.00793802307129 mask, 0.00624431030273 weights
# FEV =  0.885936900973
# Runs: 1200; MSE - train: 0.101008, val: 0.101531; lr = 0.001
# best run:  1200 0.101531
# Loss/Regularization: 0.00179424 MSE, 0.0 kernel, 0.00796292175293 mask, 0.00623635375977 weights
# FEV =  0.886301003397
# Runs: 1300; MSE - train: 0.101533, val: 0.101525; lr = 0.001
# best run:  1300 0.101525
# Loss/Regularization: 0.00178851 MSE, 0.0 kernel, 0.00799905334473 mask, 0.00622676574707 weights
# FEV =  0.88655910641
# Runs: 1400; MSE - train: 0.10131, val: 0.10152; lr = 0.001
# best run:  1400 0.10152
# Loss/Regularization: 0.00178445 MSE, 0.0 kernel, 0.00797765258789 mask, 0.00621898376465 weights
# FEV =  0.886378079653
# Runs: 1500; MSE - train: 0.102024, val: 0.101525; lr = 0.001
# best run:  1400 0.10152
# Loss/Regularization: 0.0017873 MSE, 0.0 kernel, 0.00794014465332 mask, 0.00620618103027 weights
# FEV =  0.886647246778
# Runs: 1600; MSE - train: 0.101187, val: 0.101521; lr = 0.001
# best run:  1400 0.10152
# Loss/Regularization: 0.00178306 MSE, 0.0 kernel, 0.00802806030273 mask, 0.00619617370605 weights
# FEV =  0.886808350682
# Runs: 1700; MSE - train: 0.101137, val: 0.101517; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178053 MSE, 0.0 kernel, 0.00800177246094 mask, 0.00619216186523 weights
# FEV =  0.88643514365
# Runs: 1800; MSE - train: 0.101906, val: 0.101523; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.0017864 MSE, 0.0 kernel, 0.00795341796875 mask, 0.00618212097168 weights
# FEV =  0.886693194509
# Runs: 1900; MSE - train: 0.101824, val: 0.10152; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178234 MSE, 0.0 kernel, 0.00803168945313 mask, 0.00617477294922 weights
# FEV =  0.886745058
# Runs: 2000; MSE - train: 0.101355, val: 0.101518; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178152 MSE, 0.0 kernel, 0.00801854858398 mask, 0.00617286315918 weights
# FEV =  0.886748515069
# Runs: 2100; MSE - train: 0.101813, val: 0.101521; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178147 MSE, 0.0 kernel, 0.00796131469727 mask, 0.00617188659668 weights
# FEV =  0.886900819838
# Runs: 2200; MSE - train: 0.101688, val: 0.101519; lr = 0.001
# best run:  1700 0.101517
# Loss/Regularization: 0.00177907 MSE, 0.0 kernel, 0.00802359130859 mask, 0.00616591491699 weights
# FEV =  0.884603746235
# Runs: 2300; MSE - train: 0.101673, val: 0.101552; lr = 0.0001
# best run:  1700 0.101517
# Loss/Regularization: 0.00181521 MSE, 0.0 kernel, 0.0062827746582 mask, 0.00614852905273 weights
# FEV =  0.885137036443
# Runs: 2400; MSE - train: 0.101672, val: 0.101545; lr = 0.0001
# best run:  1700 0.101517
# Loss/Regularization: 0.00180682 MSE, 0.0 kernel, 0.00628244018555 mask, 0.00615178466797 weights
# FEV =  0.885763540864
# Runs: 2500; MSE - train: 0.101432, val: 0.101535; lr = 0.0001
# best run:  1700 0.101517
# Loss/Regularization: 0.00179696 MSE, 0.0 kernel, 0.00628845031738 mask, 0.00615704223633 weights
# FEV =  0.886247709394
# Runs: 2600; MSE - train: 0.100843, val: 0.101528; lr = 0.0001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178935 MSE, 0.0 kernel, 0.00629467468262 mask, 0.00616110046387 weights
# FEV =  0.886601381004
# Runs: 2700; MSE - train: 0.101411, val: 0.101522; lr = 0.0001
# best run:  1700 0.101517
# Loss/Regularization: 0.00178378 MSE, 0.0 kernel, 0.00629531860352 mask, 0.00616369750977 weights
# ('Stop at run 2700; MSE on validation set: 0.101517', 'MSE on test set: 0.00178053; FEV: 0.886831')
# run took 229.29861855506897 s to optimize
